# %%
import pandas as pd
path=r"K:\Dashboard Delivery\data\processed\dataset_maestro_intrak_bogota.csv"
df = pd.read_csv(path)
df
# Out:
#               fecha_pedido      localidad  estrato   tipo_via    tipo_zona  \
# 0      2021-10-20 03:00:00        Kennedy        2  Destapada  Residencial
# 1      2020-02-05 20:00:00     Tunjuelito        1   Arterial   Industrial
# 2      2024-05-08 22:00:00           Suba        1    Troncal  Residencial
# 3      2025-02-06 20:00:00  Puente Aranda        2   Arterial   Industrial
# 4      2021-04-15 04:00:00       Fontibón        3   Arterial  Residencial
# ...                    ...            ...      ...        ...          ...
# 52580  2022-06-22 15:00:00        Kennedy        3    Troncal    Comercial
# 52581  2025-07-10 01:00:00        Usaquén        3      Local    Comercial
# 52582  2024-12-27 00:00:00     Tunjuelito        5    Troncal    Comercial
# 52583  2024-07-28 18:00:00     Tunjuelito        4    Troncal    Comercial
# 52584  2025-07-02 00:00:00        Kennedy        2   Arterial    Comercial
#
# ...

# %%
print(df.isnull().sum())
print("-" * 50)
print(df.dtypes)
print("-" * 50)
print(df.describe())
print("-" * 50)
df.columns
# Out:
# fecha_pedido           0
# localidad              0
# estrato                0
# tipo_via               0
# tipo_zona              0
# vehiculo               0
# distancia_km           0
# nivel_trafico          0
# lluvia_mm              0
# pendiente_promedio     0
# zona_riesgo            0
# cliente_ausente        0
# intentos_entrega       0
# tiempo_estimado_min    0
# tiempo_real_min        0
# dtype: int64
# --------------------------------------------------
# fecha_pedido            object
# localidad               object
# estrato                  int64
# tipo_via                object
# tipo_zona               object
# vehiculo                object
# distancia_km           float64
# nivel_trafico          float64
# lluvia_mm              float64
# pendiente_promedio     float64
# zona_riesgo            float64
# cliente_ausente          int64
# intentos_entrega         int64
# tiempo_estimado_min    float64
# tiempo_real_min        float64
# dtype: object
# ...
